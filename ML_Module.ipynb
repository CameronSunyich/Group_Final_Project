# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf

# %%
file_path = "./cleaned_music_data.csv"
music_df = pd.read_csv(file_path, index_col=0, encoding = "ISO-8859-1")
music_df
# Out:
#         year  acousticness                        artists  danceability  \
# 7606    1960      0.547000                 ['Etta James']         0.274
# 7607    1960      0.829000                 ['Etta James']         0.421
# 7608    1960      0.764000            ['Ella Fitzgerald']         0.508
# 7609    1960      0.733000            ['Ella Fitzgerald']         0.579
# 7610    1960      0.699000                ['Neil Sedaka']         0.743
# ...      ...           ...                            ...           ...
# 170448  2019      0.226000  ['Juanes', 'Christian Nodal']         0.757
# 170449  2019      0.001210                    ['Wallows']         0.449
# 170450  2019      0.016700               ['Boy In Space']         0.616
# 170451  2019      0.000755                   ['Paul Amp']         0.766
# 170452  2019      0.233000                      ['LUCKI']         0.780
#
#         duration_ms  energy  explicit  instrumentalness  loudness  \
# ...

# %%
# Create dummies variables for all of the text features, and store the resulting data on a DataFrame named X.
# Creating dummy variables for categorical datatypes
X = pd.get_dummies(music_df, columns=['year', 'acousticness','artists', 'danceability', 'duration_ms', 'energy', 'explicit', 'instrumentalness','loudness', 'popularity', 'tempo'])
X
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13612/86671413.py in <module>
#       1 # Create dummies variables for all of the text features, and store the resulting data on a DataFrame named X.
#       2 # Creating dummy variables for categorical datatypes
# ----> 3 X = pd.get_dummies(music_df, columns=['year', 'acousticness','artists', 'danceability', 'duration_ms', 'energy', 'explicit', 'instrumentalness','loudness', 'popularity', 'tempo'])
#       4 X
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     941                 sparse=sparse,
#     942                 drop_first=drop_first,
# --> 943                 dtype=dtype,
#     944             )
#     945             with_dummies.append(dummy)
#
# ...

# %%
# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
