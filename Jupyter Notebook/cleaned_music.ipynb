# %%
import os
import pandas as pd

path = os.path.join('C:/Users/aweso/Desktop/UO-Bootcamp/Final_Project/Resource/data.csv')
music_data = pd.read_csv(path)
music_data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
cleaned_music_data = music_data[music_data['year'] >= 1960]
cleaned_music_data = cleaned_music_data[cleaned_music_data['year'] <= 2019]
#drop mode, id, speechiness, popularity?, liveness, valence, song released?, key?
cleaned_music_data = cleaned_music_data.drop(['id'],axis = 1)
cleaned_music_data = cleaned_music_data.drop(['mode'],axis = 1)
cleaned_music_data = cleaned_music_data.drop(['speechiness'],axis = 1)
cleaned_music_data = cleaned_music_data.drop(['liveness'],axis = 1)
cleaned_music_data = cleaned_music_data.drop(['valence'],axis = 1)
cleaned_music_data = cleaned_music_data.drop(['key'],axis = 1)
cleaned_music_data = cleaned_music_data.drop(['name'],axis = 1)
cleaned_music_data = cleaned_music_data.drop(['artists'],axis = 1)
cleaned_music_data
# Out:
#         year  acousticness  danceability  duration_ms  energy  explicit  \
# 7606    1960      0.547000         0.274       179693   0.348         0
# 7607    1960      0.829000         0.421       196133   0.285         0
# 7608    1960      0.764000         0.508       175987   0.287         0
# 7609    1960      0.733000         0.579       131733   0.502         0
# 7610    1960      0.699000         0.743       139200   0.799         0
# ...      ...           ...           ...          ...     ...       ...
# 170448  2019      0.226000         0.757       159547   0.688         0
# 170449  2019      0.001210         0.449       247613   0.825         0
# 170450  2019      0.016700         0.616       203555   0.469         0
# 170451  2019      0.000755         0.766       196875   0.649         0
# 170452  2019      0.233000         0.780       132115   0.453         1
#
#         instrumentalness  loudness  popularity    tempo
# ...

# %%
cleaned_music_data.to_csv('cleaned_music_data.csv', sep=',')
