# %%
import matplotlib
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
import scipy.stats as sts

# %%
data = "./Resource/cleaned_music_data.csv"

# Read the data
data_df = pd.read_csv(data)
data_df
# Out:
#         Unnamed: 0  year  acousticness  danceability  duration_ms  energy  \
# 0             7606  1960      0.547000         0.274       179693   0.348
# 1             7607  1960      0.829000         0.421       196133   0.285
# 2             7608  1960      0.764000         0.508       175987   0.287
# 3             7609  1960      0.733000         0.579       131733   0.502
# 4             7610  1960      0.699000         0.743       139200   0.799
# ...            ...   ...           ...           ...          ...     ...
# 118715      170448  2019      0.226000         0.757       159547   0.688
# 118716      170449  2019      0.001210         0.449       247613   0.825
# 118717      170450  2019      0.016700         0.616       203555   0.469
# 118718      170451  2019      0.000755         0.766       196875   0.649
# 118719      170452  2019      0.233000         0.780       132115   0.453
#
#         explicit  instrumentalness  loudness  popularity    tempo
# ...

# %%
sixty_df = data_df[(data_df['year'] == 2010)]
sixtyone_df = data_df[(data_df['year'] == 2011)]
sixtytwo_df = data_df[(data_df['year'] == 2012)]
sixtythree_df = data_df[(data_df['year'] == 2013)]
sixtyfour_df = data_df[(data_df['year'] == 2014)]
sixtyfive_df = data_df[(data_df['year'] == 2015)]
sixtysix_df = data_df[(data_df['year'] == 2016)]
sixtyseven_df = data_df[(data_df['year'] == 2017)]
sixtyeight_df = data_df[(data_df['year'] == 2018)]
sixtynine_df = data_df[(data_df['year'] == 2019)]

# %%
# Calculate averages of tempo for each decade
sixty_tempo = sixty_df['tempo'].mean()
sixtyone_tempo = sixtyone_df['tempo'].mean()
sixtytwo_tempo = sixtytwo_df['tempo'].mean()
sixtythree_tempo = sixtythree_df['tempo'].mean()
sixtyfour_tempo = sixtyfour_df['tempo'].mean()
sixtyfive_tempo = sixtyfive_df['tempo'].mean()
sixtysix_tempo = sixtysix_df['tempo'].mean()
sixtyseven_tempo = sixtyseven_df['tempo'].mean()
sixtyeight_tempo = sixtyeight_df['tempo'].mean()
sixtynine_tempo = sixtynine_df['tempo'].mean()

# %%
# Calculate averages of tempo for each decade
sixty_duration = sixty_df['duration_ms'].mean()
sixtyone_duration = sixtyone_df['duration_ms'].mean()
sixtytwo_duration = sixtytwo_df['duration_ms'].mean()
sixtythree_duration = sixtythree_df['duration_ms'].mean()
sixtyfour_duration = sixtyfour_df['duration_ms'].mean()
sixtyfive_duration = sixtyfive_df['duration_ms'].mean()
sixtysix_duration = sixtysix_df['duration_ms'].mean()
sixtyseven_duration = sixtyseven_df['duration_ms'].mean()
sixtyeight_duration = sixtyeight_df['duration_ms'].mean()
sixtynine_duration = sixtynine_df['duration_ms'].mean()

# %%
# Calculate averages of tempo for each decade
sixty_loudness = sixty_df['loudness'].mean()
sixtyone_loudness = sixtyone_df['loudness'].mean()
sixtytwo_loudness = sixtytwo_df['loudness'].mean()
sixtythree_loudness = sixtythree_df['loudness'].mean()
sixtyfour_loudness = sixtyfour_df['loudness'].mean()
sixtyfive_loudness = sixtyfive_df['loudness'].mean()
sixtysix_loudness = sixtysix_df['loudness'].mean()
sixtyseven_loudness = sixtyseven_df['loudness'].mean()
sixtyeight_loudness = sixtyeight_df['loudness'].mean()
sixtynine_loudness = sixtynine_df['loudness'].mean()

# %%
# Calculate averages of tempo for each decade
sixty_danceability = sixty_df['danceability'].mean()
sixtyone_danceability = sixtyone_df['danceability'].mean()
sixtytwo_danceability = sixtytwo_df['danceability'].mean()
sixtythree_danceability = sixtythree_df['danceability'].mean()
sixtyfour_danceability = sixtyfour_df['danceability'].mean()
sixtyfive_danceability = sixtyfive_df['danceability'].mean()
sixtysix_danceability = sixtysix_df['danceability'].mean()
sixtyseven_danceability = sixtyseven_df['danceability'].mean()
sixtyeight_danceability = sixtyeight_df['danceability'].mean()
sixtynine_danceability = sixtynine_df['danceability'].mean()

# %%
# Calculate averages of tempo for each decade
sixty_energy = sixty_df['energy'].mean()
sixtyone_energy = sixtyone_df['energy'].mean()
sixtytwo_energy = sixtytwo_df['energy'].mean()
sixtythree_energy = sixtythree_df['energy'].mean()
sixtyfour_energy = sixtyfour_df['energy'].mean()
sixtyfive_energy = sixtyfive_df['energy'].mean()
sixtysix_energy = sixtysix_df['energy'].mean()
sixtyseven_energy = sixtyseven_df['energy'].mean()
sixtyeight_energy = sixtyeight_df['energy'].mean()
sixtynine_energy = sixtynine_df['energy'].mean()

# %%
# Calculate averages of tempo for each decade
sixty_explicit = sixty_df['explicit'].mean()
sixtyone_explicit = sixtyone_df['explicit'].mean()
sixtytwo_explicit = sixtytwo_df['explicit'].mean()
sixtythree_explicit = sixtythree_df['explicit'].mean()
sixtyfour_explicit = sixtyfour_df['explicit'].mean()
sixtyfive_explicit = sixtyfive_df['explicit'].mean()
sixtysix_explicit = sixtysix_df['explicit'].mean()
sixtyseven_explicit = sixtyseven_df['explicit'].mean()
sixtyeight_explicit = sixtyeight_df['explicit'].mean()
sixtynine_explicit = sixtynine_df['explicit'].mean()

# %%
# Calculate averages of tempo for each decade
sixty_popularity = sixty_df['popularity'].mean()
sixtyone_popularity = sixtyone_df['popularity'].mean()
sixtytwo_popularity = sixtytwo_df['popularity'].mean()
sixtythree_popularity = sixtythree_df['popularity'].mean()
sixtyfour_popularity = sixtyfour_df['popularity'].mean()
sixtyfive_popularity = sixtyfive_df['popularity'].mean()
sixtysix_popularity = sixtysix_df['popularity'].mean()
sixtyseven_popularity = sixtyseven_df['popularity'].mean()
sixtyeight_popularity = sixtyeight_df['popularity'].mean()
sixtynine_popularity = sixtynine_df['popularity'].mean()

# %%
# Calculate averages of tempo for each decade
sixty_acousticness = sixty_df['acousticness'].mean()
sixtyone_acousticness = sixtyone_df['acousticness'].mean()
sixtytwo_acousticness = sixtytwo_df['acousticness'].mean()
sixtythree_acousticness = sixtythree_df['acousticness'].mean()
sixtyfour_acousticness = sixtyfour_df['acousticness'].mean()
sixtyfive_acousticness = sixtyfive_df['acousticness'].mean()
sixtysix_acousticness = sixtysix_df['acousticness'].mean()
sixtyseven_acousticness = sixtyseven_df['acousticness'].mean()
sixtyeight_acousticness = sixtyeight_df['acousticness'].mean()
sixtynine_acousticness = sixtynine_df['acousticness'].mean()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_tempo, sixtyone_tempo, sixtytwo_tempo, sixtythree_tempo, sixtyfour_tempo, sixtyfive_tempo, sixtysix_tempo, sixtyseven_tempo, sixtyeight_tempo, sixtynine_tempo]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Tempo')
plt.title('Tempo In Music Trend 2010-2019')
plt.show()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_duration, sixtyone_duration, sixtytwo_duration, sixtythree_duration, sixtyfour_duration, sixtyfive_duration, sixtysix_duration, sixtyseven_duration, sixtyeight_duration, sixtynine_duration]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Duration')
plt.title('Duration In Music Trend 2010-2019')
plt.show()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_loudness, sixtyone_loudness, sixtytwo_loudness, sixtythree_loudness, sixtyfour_loudness, sixtyfive_loudness, sixtysix_loudness, sixtyseven_loudness, sixtyeight_loudness, sixtynine_loudness]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Loudness')
plt.title('Loudness In Music Trend 2010-2019')
plt.show()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_danceability, sixtyone_danceability, sixtytwo_danceability, sixtythree_danceability, sixtyfour_danceability, sixtyfive_danceability, sixtysix_danceability, sixtyseven_danceability, sixtyeight_danceability, sixtynine_danceability]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Danceability')
plt.title('Danceability In Music Trend 2010-2019')
plt.show()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_energy, sixtyone_energy, sixtytwo_energy, sixtythree_energy, sixtyfour_energy, sixtyfive_energy, sixtysix_energy, sixtyseven_energy, sixtyeight_energy, sixtynine_energy]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Energy')
plt.title('Energy In Music Trend 2010-2019')
plt.show()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_explicit, sixtyone_explicit, sixtytwo_explicit, sixtythree_explicit, sixtyfour_explicit, sixtyfive_explicit, sixtysix_explicit, sixtyseven_explicit, sixtyeight_explicit, sixtynine_explicit]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Explicit')
plt.title('Explicit In Music Trend 2010-2019')
plt.show()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_popularity, sixtyone_popularity, sixtytwo_popularity, sixtythree_popularity, sixtyfour_popularity, sixtyfive_popularity, sixtysix_popularity, sixtyseven_popularity, sixtyeight_popularity, sixtynine_popularity]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Popularity')
plt.title('Popularity In Music Trend 2010-2019')
plt.show()

# %%
plt.figure(figsize=(12,12))
x_axis =['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
y_axis =[sixty_acousticness, sixtyone_acousticness, sixtytwo_acousticness, sixtythree_acousticness, sixtyfour_acousticness, sixtyfive_acousticness, sixtysix_acousticness, sixtyseven_acousticness, sixtyeight_acousticness, sixtynine_acousticness]
plt.bar(x_axis, y_axis)
plt.xlabel('Year')
plt.ylabel('Acousticness')
plt.title('Acousticness In Music Trend 2010-2019')
plt.show()
